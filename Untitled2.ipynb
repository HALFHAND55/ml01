# %% [markdown]
# <a href="https://colab.research.google.com/github/HALFHAND55/ml01/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
d=pd.read_csv('/content/diabetes2[1].csv')
d
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# d.describe()

# %%
d['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
d.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
x=d.drop(columns='Outcome',axis=1)
y=d['Outcome']
print(x)
print(y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 619            0      119              0              0        0  32.4
# 329            6      105             70             32       68  30.8
# 13             1      189             60             23      846  30.1
# 476            2      105             80             45      191  33.7
# 45             0      180             66             39        0  42.0
# ..           ...      ...            ...            ...      ...   ...
# 303            5      115             98              0        0  52.9
# 592            3      132             80              0        0  34.4
# 559           11       85             74              0        0  30.1
# 725            4      112             78             40        0  39.4
# 253            0       86             68             32        0  35.8
#
#      DiabetesPedigreeFunction  Age
# 619                     0.141   24
# 329                     0.122   37
# ...

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 615            3      106             72              0        0  25.8
# 80             3      113             44             13        0  22.4
# 148            5      147             78              0        0  33.7
# 132            3      170             64             37      225  34.5
# 501            3       84             72             32        0  37.2
# ..           ...      ...            ...            ...      ...   ...
# 127            1      118             58             36       94  33.3
# 185            7      194             68             28        0  35.9
# 85             2      110             74             29      125  32.4
# 497            2       81             72             15       76  30.1
# 86            13      106             72             54        0  36.6
#
#      DiabetesPedigreeFunction  Age
# 615                     0.207   27
# 80                      0.140   22
# ...

# %%
scale=StandardScaler()
scale.fit(x_train)
sd=scale.transform(x_train)
sd
# Out:
# array([[-1.13796489, -0.07971099, -3.5556072 , ...,  0.02825037,
#         -0.98159708, -0.7885233 ],
#        [ 0.64067858, -0.52091877,  0.02549599, ..., -0.17184452,
#         -1.03823795,  0.31879426],
#        [-0.84152431,  2.12632792, -0.48609018, ..., -0.25938604,
#         -0.21545477,  2.19271628],
#        ...,
#        [ 2.12288146, -1.15121561,  0.23013046, ..., -0.25938604,
#         -0.50760242,  0.14843771],
#        [ 0.04779742, -0.30031488,  0.43476492, ...,  0.90366551,
#         -0.69839272,  0.40397253],
#        [-1.13796489, -1.11970076, -0.07682125, ...,  0.45345201,
#         -0.69243053, -0.70334503]])

# %%
classifier=svm.SVC(kernel='linear')
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
 x_pred=classifier.predict(x_train)
 data_acc=accuracy_score(x_pred,y_train)
 data_acc
 type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
test_pred=classifier.predict(x_test)
test_acc=accuracy_score(test_pred,y_test)
test_acc
# Out:
# 0.7727272727272727

# %%
import pickle
pickle.dump(classifier,open('firstml','wb'))
